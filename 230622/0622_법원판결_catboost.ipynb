# %% [markdown]
# # Full Flow
# 0. EDA
# 1. 파생변수 생성
# 2. 데이터 전처리
#    - 특수문자 및 기호 등 필요없는 문자 제거
#    - 대소문자 모두 소문자로 통일
#    - 이름 | 불용어(분석에 필요없는 토큰) 제거 => TF-IDF 적용시 해결 가능, 이름 제거하는게 낫나 아니면 살리는게 낫나
#    - 어근 추츨을 통한 텍스트 정규화 작업
#    ----------------------------------
#    - TF-IDF
#    ---------------------------------
#    - 벡터화 함수 적용
#    ---------------------------------
#    - 타켓 변수 불균형 해결
# 3. 모델 적합
#   **CatBoost**
# 4. 하이퍼파라미터튜닝
#   - optuna
# 5. 모델 앙상블

# %% [markdown]
# # CatBoost
# Catboost는 이름에서도 유추 가능하듯이 Cat, Category 즉 범주형 변수가 많은 데이터를 학습할 때 성능이 좋음
#
# https://julie-tech.tistory.com/119

# %% [markdown]
# # 라이브러리 및 데이터 불러오기

# %%
# !pip install catboost

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer
# Catboost 모델링
from catboost import CatBoostClassifier, Pool

# %%
import nltk # 문장 토크나이저
nltk.download('all')

from nltk.corpus import names #corpus=말뭉치,이름 관련 부분 다루기 위한 객체

from nltk.corpus import stopwords # 영어 불용어 - 불용어 모아 놓은 리스트 다운로드해 제거

from nltk.tokenize import word_tokenize # 토큰화
from nltk.stem.porter import PorterStemmer # 어근 동일화 <-> 이거 말고도 "Lancaster Stemmer"

# 표제어 추출
from nltk.stem import WordNetLemmatizer

# 정규표현 처리
import re

# %%
# 구글 드라이브에서 데이터 불러오기
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import zipfile

# ZIP 파일 열기
with zipfile.ZipFile('/content/gdrive/MyDrive/0000/dacon_lawwinner/open.zip', 'r') as zip_ref:
    # 파일 목록 가져오기
    file_list = zip_ref.namelist()

    # 파일 목록 출력
    for file in file_list:
        print(file)

    # 모든 파일 압축 해제
    zip_ref.extractall()
# Out:
# sample_submission.csv
# test.csv
# train.csv

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("/content/test.csv")
sample_submission = pd.read_csv("/content/sample_submission.csv")

# %% [markdown]
# # 파생변수 생성

# %% [markdown]
# ### 문장, 단어 길이 컬럼

# %%
train['sen_len'] = 0 # 문장 토큰화
train['word_len'] = 0 # 단어 토큰화

for i in range(len(train)):
  train.sen_len[i] = len(nltk.sent_tokenize(train.facts[i]))
  train.word_len[i] = len(word_tokenize(train.facts[i]))

train = train[['ID', 'first_party', 'second_party', 'facts', 'sen_len', 'word_len', 'first_party_winner']]
train.head(10)
# Out:
#            ID                  first_party                    second_party  \
# 0  TRAIN_0000            Phil A. St. Amant              Herman A. Thompson
# 1  TRAIN_0001               Stephen Duncan                  Lawrence Owens
# 2  TRAIN_0002            Billy Joe Magwood  Tony Patterson, Warden, et al.
# 3  TRAIN_0003                   Linkletter                          Walker
# 4  TRAIN_0004           William Earl Fikes                         Alabama
# 5  TRAIN_0005  C & A Carbone, Inc., et al.              Town of Clarkstown
# 6  TRAIN_0006       David Jennings, et al.     Alejandro Rodriguez, et al.
# 7  TRAIN_0007             US Airways, Inc.                         Barnett
# 8  TRAIN_0008     Ron Davis, Acting Warden                    Hector Ayala
# 9  TRAIN_0009             Paul A. McDaniel         Selma Cash Paty, et al.
#
#                                                facts  sen_len  word_len  \
# 0  On June 27, 1962, Phil St. Amant, a candidate ...        7       201
# 1  Ramon Nelson was riding his bike when he suffe...        7       219
# 2  An Alabama state court convicted Billy Joe Mag...        8       191
# 3  Victor Linkletter was convicted in state court...        3        59
# 4  On April 24, 1953 in Selma, Alabama, an intrud...        9       200
# 5  A New York town, Clarkstown, allowed a contrac...       11       210
# 6  Sections of the Immigration and Nationality Ac...        7       264
# 7  In 1990, Robert Barnett injured his back while...        6       205
# 8  Hector Ayala, a Hispanic man, was charged with...       12       478
# 9  Since its first state Constitution in 1796, Te...        7       144
#
#    first_party_winner
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   1
# 5                   1
# 6                   1
# 7                   1
# 8                   1
# 9                   1

# %%
test['sen_len'] = 0 # 문장 토큰화
test['word_len'] = 0 # 단어 토큰화

for i in range(len(test)):
  test.sen_len[i] = len(nltk.sent_tokenize(test.facts[i]))
  test.word_len[i] = len(word_tokenize(test.facts[i]))

test = test[['ID', 'first_party', 'second_party', 'facts', 'sen_len', 'word_len']]
test.head(10)
# Out:
#           ID                                        first_party  \
# 0  TEST_0000                                            Salerno
# 1  TEST_0001             Milberg Weiss Bershad Hynes and Lerach
# 2  TEST_0002  No. 07-582\t Title: \t Federal Communications ...
# 3  TEST_0003                                    Harold Kaufman
# 4  TEST_0004                                             Berger
# 5  TEST_0005                        Air Line Pilots Association
# 6  TEST_0006           Traffic Stream (BVI) Infrastructure Ltd.
# 7  TEST_0007                     NRG Power Marketing LLC et al.
# 8  TEST_0008                                      United States
# 9  TEST_0009                  United States Catholic Conference
#
#                                second_party  \
# 0                             United States
# 1                             Lexecon, Inc.
# 2     Fox Television Stations, Inc., et al.
# 3                             United States
# 4                                    Hanlon
# 5                                    Miller
# 6                       JPMorgan Chase Bank
# 7  Maine Public Utilities Commission et al.
# 8                         Deondery Chambers
# 9        Abortion Rights Mobilization, Inc.
#
#                                                facts  sen_len  word_len
# 0  The 1984 Bail Reform Act allowed the federal c...        2        55
# 1  Lexecon Inc. was a defendant in a class action...        7       209
# 2  In 2002 and 2003, Fox Television Stations broa...        7       181
# 3  During his trial for armed robbery of a federa...        6        99
# 4  In 1993, a magistrate judge issued a warrant a...        6       154
# 5  The Air Line Pilots Association (ALPA), a priv...        9       163
# 6  Traffic Stream (BVI) Infrastructure Ltd. is a ...        5       177
# 7  The Maine Public Utilities Commission along wi...        7       194
# 8  Deondery Chambers pled guilty to being a felon...        8       243
# 9  Abortion Rights Mobilization, Inc. and a colle...        6       225

# %% [markdown]
# ### issued_area

# %%
# 유형 분류 : 28개
df = pd.read_csv('https://s3.ap-northeast-2.amazonaws.com/data10902/messy/crime_clean.csv',encoding='utf-8')
df.소분류.unique()

# %%
# 캐글:샌프란시스코 범죄 유형 분류
# https://www.kaggle.com/c/sf-crime
# https://www.kaggle.com/code/yannisp/sf-crime-analysis-prediction

# %% [markdown]
# - Larceny/Theft
# - Non/Criminal
# - Assault

# %% [markdown]
# ### 승률 현황
# **first_party_win_percent**
#   첫 번째 당사자가 승소할 확률.
# - 출현 빈도가 2이상일때만 반영함. 1일때는 0.5
# - test에서는 first_party가 train의 first_party와 겹치는 경우에는 해당 사람의 승소할 확률을 반영함. 겹치지 않는 경우는 0.5로 반영함.

# %%
# winner: 해당 사건에서 승소한 사람
# win_percentage: 승소한 사람이 다른 사건에서도 승소할 확률

train['winner']=0
for i in range(2477):
  if train['first_party_winner'][i]==1:
    train['winner'][i] = train['first_party'][i]
  else:
    train['winner'][i] = train['second_party'][i]

train['win_percentage']=0
for i in range(2477):
  winner_exp = len(train.loc[train['first_party'] == train['winner'][i]])
  loose_exp = len(train.loc[train['second_party'] == train['winner'][i]])
  train['win_percentage'][i]= len(train.loc[train['winner'] == train['winner'][i]]) /(winner_exp + loose_exp)

# %%
# first_party_frequency: first_party가 나타난 빈도
# first_party_win_percent: first_party가 승소할 확률
train['first_party_win_percent'] = 0
train['first_party_frequency'] = 0

for i in range(2477):
  train['first_party_frequency'][i] = len(train.loc[train['first_party'] == train['first_party'][i]]) + len(train.loc[train['second_party'] == train['first_party'][i]])

  # 출현 빈도가 2이상일때만 반영함. 1일때는 0.5
  if train['first_party_frequency'][i] > 1:
    p = len(train.loc[train['winner'] == train['first_party'][i]]) / train['first_party_frequency'][i]
    train['first_party_win_percent'][i] = p
  else:
    train['first_party_win_percent'][i] = 0.5

# %%
train = train.drop(['winner',	'win_percentage'],axis=1)
train.tail(30)
# Out:
#               ID                                      first_party  \
# 2448  TRAIN_2448                                     Pennsylvania
# 2449  TRAIN_2449                                  WesternGeco LLC
# 2450  TRAIN_2450                                          Helling
# 2451  TRAIN_2451                             Hana Financial, Inc.
# 2452  TRAIN_2452         Police Department of the City of Chicago
# 2453  TRAIN_2453                            City of Oklahoma City
# 2454  TRAIN_2454                                          Rotella
# 2455  TRAIN_2455                             Gregory Houston Holt
# 2456  TRAIN_2456                                    United States
# 2457  TRAIN_2457                                           Crosby
# 2458  TRAIN_2458                                     Dollree Mapp
# 2459  TRAIN_2459                               Stephanie C. Artis
# 2460  TRAIN_2460  Alaska Department of Environmental Conservation
# 2461  TRAIN_2461                                          Cicenia
# 2462  TRAIN_2462                   Central Bank of Denver , N. A.
# 2463  TRAIN_2463                              Keith Lance, et al.
# 2464  TRAIN_2464                                    United States
# 2465  TRAIN_2465                                    Andrew Kisela
# 2466  TRAIN_2466                                Monroe Ace Setser
# 2467  TRAIN_2467                   Central Laborers' Pension Fund
# 2468  TRAIN_2468                                Monty Lee Eddings
# 2469  TRAIN_2469                                         Ferguson
# 2470  TRAIN_2470                   Bethel School District No. 403
# 2471  TRAIN_2471                                    United States
# 2472  TRAIN_2472                                    United States
# 2473  TRAIN_2473     HollyFrontier Cheyenne Refining, LLC, et al.
# 2474  TRAIN_2474              Grupo Mexicano de Desarrollo, S. A.
# 2475  TRAIN_2475                                          Peguero
# 2476  TRAIN_2476           Immigration and Naturalization Service
# 2477  TRAIN_2477                                          Markman
#
#                                            second_party  \
# 2448    Delaware Valley Citizens' Council for Clean Air
# 2449                        ION Geophysical Corporation
# 2450                                           McKinney
# 2451                                  Hana Bank, et al.
# 2452                                             Mosley
# 2453  Rose Marie Tuttle, Individually and as Adminis...
# 2454                                               Wood
# 2455  Ray Hobbs, Director, Arkansas Department of Co...
# 2456                                             Lanier
# 2457                     National Foreign Trade Council
# 2458                                               Ohio
# 2459                               District of Columbia
# 2460            Environmental Protection Agency, et al.
# 2461                                              Lagay
# 2462     First Interstate Bank Of Denver, N. A., et al.
# 2463           Gigi Dennis, Colorado Secretary of State
# 2464                                  Henry Ogle Watson
# 2465                                         Amy Hughes
# 2466                                      United States
# 2467                            Thomas E. Heinz, et al.
# 2468                                           Oklahoma
# 2469                                 City of Charleston
# 2470  Matthew N. Fraser, a minor, and E.L. Fraser, G...
# 2471                                    James X. Bormes
# 2472                          Cuauhtemoc Gonzalez-Lopez
# 2473                Renewable Fuels Association, et al.
# 2474                           Alliance Bond Fund, Inc.
# 2475                                      United States
# 2476                                            St. Cyr
# 2477                         Westview Instruments, Inc.
#
#                                                   facts  sen_len  word_len  \
# 2448  In April of 1973, pursuant to the Clean Air Ac...       13       394
# 2449  The US Supreme Court issued a 2016 order grant...        9       254
# 2450  William McKinney, a Nevada state prisoner, sue...        4       163
# 2451  In the spring of 1994, Hana Bank, a Korean ent...       10       304
# 2452  Chicago adopted an ordinance prohibiting picke...        3        54
# 2453  On October 10, 1980, an Oklahoma City police o...        5       180
# 2454  Mark Rotella was admitted to a Brookhaven Psyc...        8       254
# 2455  Gregory Holt (also known as Abdul Maalik Muham...        6       190
# 2456  David W. Lanier was convicted under 18 U.S.C. ...        7       223
# 2457  In 1996, the Massachusetts Burma Law, which re...        7       189
# 2458  Dollree Mapp was convicted of possessing obsce...        2        33
# 2459  In 2007, Stephanie Artis was employed by the D...       10       272
# 2460  Under the Clean Air Act, state agencies must d...        7       174
# 2461  During police interrogation for a murder, Cice...        6       139
# 2462  In 1986 and 1988, the Colorado Springs-Stetson...        8       168
# 2463  When the Colorado legislature failed to pass a...        8       220
# 2464  On August 17, 1972, a postal inspector receive...       12       256
# 2465  Tucson police officer Andrew Kisela and two ot...        8       203
# 2466  On October 1, 2007, Lubbock police officers ar...        8       187
# 2467  Thomas Heinz worked as a construction worker f...       14       341
# 2468  On April 4, 1977, sixteen-year-old Monty Lee E...       15       408
# 2469  After an increase in the use of cocaine by pat...        6       150
# 2470  At a school assembly of approximately 600 high...        7        94
# 2471  In October 2000, the United States Treasury De...       14       403
# 2472  Cuauhtemoc Gonzalez-Lopez hired Joseph Low, an...        6       146
# 2473  Congress amended the Clean Air Act through the...        5       144
# 2474  Alliance Bond Fund, Inc., an investment fund, ...        7       184
# 2475  In 1992, the District Court sentenced Manuel D...        6       195
# 2476  On March 8, 1996, Enrico St. Cyr, a lawful per...        8       194
# 2477  Herbert Markman owns the patent to a system th...        6       205
#
#       first_party_winner  first_party_win_percent  first_party_frequency
# 2448                   1                  0.62500                      8
# 2449                   1                  0.50000                      1
# 2450                   0                  0.50000                      1
# 2451                   0                  0.50000                      1
# 2452                   0                  0.50000                      1
# 2453                   1                  0.50000                      1
# 2454                   0                  0.50000                      1
# 2455                   1                  0.50000                      1
# 2456                   1                  0.57868                    394
# 2457                   0                  0.50000                      1
# 2458                   1                  0.50000                      1
# 2459                   1                  0.50000                      1
# 2460                   0                  0.50000                      1
# 2461                   0                  0.50000                      1
# 2462                   1                  0.50000                      1
# 2463                   1                  0.50000                      1
# 2464                   1                  0.57868                    394
# 2465                   1                  0.50000                      1
# 2466                   0                  0.50000                      1
# 2467                   0                  0.50000                      1
# 2468                   1                  0.50000                      1
# 2469                   1                  0.50000                      1
# 2470                   1                  0.50000                      1
# 2471                   1                  0.57868                    394
# 2472                   0                  0.57868                    394
# 2473                   1                  0.50000                      1
# 2474                   1                  0.50000                      1
# 2475                   0                  0.50000                      1
# 2476                   0                  0.80000                      5
# 2477                   0                  0.00000                      0

# %% [markdown]
# # Data Preprocessing

# %%
# 영어 데이터 전처리 함수
stops = set(stopwords.words('english'))
stemmer = nltk.stem.SnowballStemmer('english')

def cleaning(str):
    replaceAll = str

    # 특수문자 및 기호 등 필요없는 문자 제거
    only_english = re.sub('[^a-zA-Z]', ' ', replaceAll)

    # 대소문자 모두 소문자로 통일
    no_capitals = only_english.lower().split()

    # 이름, 불용어(분석에 필요없는 토큰) 제거
    all_names=set(names.words())
    no_stops = [word for word in no_capitals if not word in all_names]

    # 어근 추츨을 통한 텍스트 정규화 작업
    stemmer_words = [stemmer.stem(word) for word in no_stops]
    return ' '.join(stemmer_words)

# %%
vectorizer = TfidfVectorizer()

def get_vector(vectorizer, df, train_mode):
    # 데이터 클리닝
    df['fact_processing'] = df['facts'].apply(cleaning)

    # TF-IDF -- 파라미터 조정 필요?
    if train_mode:
        X_facts = vectorizer.fit_transform(df['fact_processing'])
    else:
        X_facts = vectorizer.transform(df['fact_processing'])

    X_party1 = vectorizer.transform(df['first_party'])
    X_party2 = vectorizer.transform(df['second_party'])

    X = np.concatenate([X_party1.todense(), X_party2.todense(), X_facts.todense()], axis=1)
    return X

# %%
# 벡터화 함수 적용
X = get_vector(vectorizer, train, True)
Y = train["first_party_winner"]
X_train = np.asarray(X) # np.array 활용 및 적용
Y_train = np.asarray(Y)

X_test = get_vector(vectorizer, test, False)

# %% [markdown]
# # Define Model & Train

# %% [markdown]
# ## self weight
# 전체 데이터에서 1:0=66:33 인 비율로, 이를 해결하기 위해 클래스별 가중치를 계산해 이를 고려해 학습 시도.
# 따라서 y값 데이터의 불균형 해결
#
# + 다른 방법으로 해결하고 싶다면
# + +) 타겟 변수 불균형 문제가 있어 클래스별 가중치를 적용해 모델 학습을 진행

# %%
counts = list(Y.value_counts())
class_weight = [counts[1]/sum(counts), counts[0]/sum(counts)]
print("weight :", class_weight)
# Out:
# weight : [0.33454398708635996, 0.66545601291364]

# %% [markdown]
# ## 모델 적합

# %%
model = CatBoostClassifier(random_seed=42,class_weights=class_weight, verbose=0)
model.fit(X_train, Y_train)

# %% [markdown]
# ## 파라미터 튜닝

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {
    'n_estimators': [100, 200,300.400,500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

grid = GridSearchCV(CatBoostClassifier(), param_grid, refit = True, verbose = 3)

# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=nan total time=  43.7s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=nan total time=  44.9s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=nan total time=  38.6s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=nan total time=  40.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=100;, score=nan total time=  40.8s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=nan total time=  46.1s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=nan total time=  39.4s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=nan total time=  40.9s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=nan total time=  39.5s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=200;, score=nan total time=  40.3s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300.4;, score=nan total time=  39.8s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300.4;, score=nan total time=  40.3s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300.4;, score=nan total time=  39.9s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300.4;, score=nan total time=  39.6s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=300.4;, score=nan total time=  39.7s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=500;, score=nan total time=  40.1s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=500;, score=nan total time=  41.1s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=500;, score=nan total time=  42.1s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=500;, score=nan total time=  40.4s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=auto, n_estimators=500;, score=nan total time=  40.7s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=nan total time=  38.8s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=nan total time=  39.3s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=nan total time=  38.6s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=nan total time=  46.0s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=100;, score=nan total time=  51.0s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=nan total time=  43.6s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=nan total time=  43.6s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=nan total time=  39.6s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=nan total time=  39.6s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=200;, score=nan total time=  52.6s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300.4;, score=nan total time=  41.7s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300.4;, score=nan total time=  41.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300.4;, score=nan total time=  44.5s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300.4;, score=nan total time=  39.3s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=300.4;, score=nan total time=  38.8s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=500;, score=nan total time=  39.3s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=500;, score=nan total time=  38.6s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=500;, score=nan total time=  38.4s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=500;, score=nan total time=  40.2s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=sqrt, n_estimators=500;, score=nan total time=  40.1s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=nan total time=  38.7s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=nan total time=  39.8s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=nan total time=  38.4s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=nan total time=  38.9s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=100;, score=nan total time=  40.5s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=nan total time=  38.7s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=nan total time=  38.9s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=nan total time=  38.8s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=nan total time=  38.2s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=200;, score=nan total time=  40.4s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300.4;, score=nan total time=  38.8s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300.4;, score=nan total time=  39.5s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300.4;, score=nan total time=  38.7s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300.4;, score=nan total time=  39.4s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=300.4;, score=nan total time=  38.2s
# [CV 1/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=500;, score=nan total time=  38.4s
# [CV 2/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=500;, score=nan total time=  39.2s
# [CV 3/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=500;, score=nan total time=  38.7s
# [CV 4/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=500;, score=nan total time=  38.8s
# [CV 5/5] END criterion=gini, max_depth=4, max_features=log2, n_estimators=500;, score=nan total time=  38.9s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=  39.3s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=  38.1s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=  36.6s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=  39.3s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=  38.1s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=nan total time=  39.7s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=nan total time=  38.5s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=nan total time=  38.4s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=nan total time=  38.1s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=200;, score=nan total time=  39.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300.4;, score=nan total time=  37.9s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300.4;, score=nan total time=  39.4s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300.4;, score=nan total time=  36.8s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300.4;, score=nan total time=  38.2s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=300.4;, score=nan total time=  37.9s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=  40.5s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=  39.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=  39.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=  36.3s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=  40.0s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=nan total time=  38.0s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=nan total time=  41.3s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=nan total time=  38.3s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=nan total time=  40.5s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=100;, score=nan total time=  40.2s
# [CV 1/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=nan total time=  40.1s
# [CV 2/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=nan total time=  38.0s
# [CV 3/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=nan total time=  39.0s
# [CV 4/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=nan total time=  40.9s
# [CV 5/5] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=200;, score=nan total time=  39.5s

# %% [markdown]
# # Inference & Submission

# %%
submit = pd.read_csv('./sample_submission.csv')

# %%
X_test = np.asarray(X_test)
Y_pred = model.predict(X_test)

# %%
submit['first_party_winner'] = Y_pred
submit.to_csv('./submit_catboost2.csv', index=False)
print('Done')
# Out:
# Done
